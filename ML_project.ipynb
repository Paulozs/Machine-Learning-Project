# %% [markdown]
# # 50.007 Machine Learning Project
#
# ____

# %%
import pandas as pd
import numpy as np
from collections import Counter

# %% [markdown]
# ### read_dataset(datapath, labeled)
# - datapath: "./Data/whic folder/which file"
# - labeled: If True returns {"label":[all emissions]}, If False returns [all emissions]

# %%
##if labelled = true returns a dict
def read_dataset(datapath, labeled=True):
    data = open(datapath)
    data_read = data.read()
    states = {}
    state_emission = data_read.split("\n")
    filtered_state_emission= [word for word in state_emission if word.strip()!= ""]
    results = filtered_state_emission
    if(labeled):
        pairs = [tuple(pair.split()) for pair in filtered_state_emission]
        for pair in pairs:
            if pair[1] not in states.keys():
                states.update({pair[1]:[pair[0]]})
            elif pair[1] in states.keys():
                states[pair[1]].append(pair[0])
        results = states
    return results

ES_train = read_dataset("./Data/ES/train")
ES_dev = read_dataset("./Data/ES/dev.in",False)
ES_devout = read_dataset("./Data/ES/dev.out")
print(ES_train)
print(ES_dev)
print(ES_devout)
# Out:
# {'O': ['Estuvimos', 'hace', 'poco', 'mi', 'pareja', 'y', 'yo', 'comiendo', 'y', 'resultó', 'todo', 'muy', 'bien', ',', 'tanto', 'la', ',', 'el', ',', 'el', ',', 'la', '…', 'nos', 'gustó', 'todo', 'mucho', '.', 'Por', 'poner', 'algún', 'pero', ',', 'quizá', 'el', 'no', 'era', 'todo', 'lo', '"', 'ibérico', '"', 'que', 'cabía', 'esperar', '.', 'Bien', 'lo', 'sabe', 'el', 'autor', 'del', 'blog', '.', ')', 'exquisita', '.', 'diferente', ',', 'creativo', 'y', 'agradable', '.', 'Si', 'no', 'has', 'probado', 'sus', 'te', 'estas', 'perdiendo', 'algo', 'muy', 'grande', '!', 'En', 'resumen', ',', 'bien-muy', 'bien', ',', 'correcto', 'y', 'profesional', '02-12-', '2012', 'elegimos', 'este', 'por', 'los', 'comentarios', ',', 'pero', 'ha', 'sido', 'una', 'Grandisima', 'Decepción', '.', 'Salimos', 'encantadas', 'del', '.', 'Ubicación', 'Comimos', 'muy', 'bien', 'y', 'bien', 'atendidos', '.', 'Los', 'en', 'estado', 'lamentable', ',', 'y', 'los', ',', 'etc', '.', '<->', 'resecas', 'y', 'no', 'sabemos', 'por', 'que', ',', 'pero', 'lo', 'llenaron', 'con', 'trozos', 'de', 'esa', '"', '"', 'que', 'era', 'casi', 'caucho-imposible', 'de', 'comer', '.', 'Por', 'supuesto', 'que', 'ya', 'estoy', 'dando', 'voces', 'para', 'avisar', 'a', 'todas', 'mis', 'relaciones', '.', 'de', 'Borja', '.', 'Alagarmos', 'la', 'cena', 'hasta', 'las', 'tres', 'tomando', 'copas', '.', 'Ofrecen', 'merluza', 'con', 'salsa', '.', 'El', 'igual', '.', 'Me', 'invitaron', 'a', 'este', 'restaurante', 'del', 'cual', 'desconocia', 'su', 'existencia', '.', 'De', 'todas', 'formas', 'decidimos', 'quedarnos', '.', 'este', 'domingo', '15', 'de', 'marzo', 'me', 'desplace', 'desde', 'galicia', 'con', 'unos', 'amigos', 'para', 'competir', 'en', 'la', 'maraton', 'de', 'bcn', '.', 'Para', 'guiris', '.', 'la', 'impresionante', ',', 'el', 'igual', 'y', 'una', 'atencion', 'con', 'tanto', 'aperitivo', 'que', 'no', 'es', 'ni', 'normal', 'de', 'bueno', ',', 'es', 'un', 'para', 'recomendar', 'a', 'todos', 'los', 'amigos', 'Calidad', 'de', 'los', 'y', 'excelente', 'de', 'mesas', ',', 'se', 'mostraron', 'muy', 'atentos', 'en', 'todo', 'momento', '-', 'un', '10', 'Excelentes', ',', 'muy', 'buena', 'e', 'inmejorable', '…', 'digno', 'de', 'probar', '.', 'Las', 'son', 'superiores', '.', 'Se', 'podria', 'mejorar', 'la', 'en', 'la', 'planta', 'superior', ',', 'demasiada', 'luz', 'plana', '.', 'Tienen', 'una', 'bastante', 'extensa', 'donde', 'cada', 'plato', 'parece', 'mejor', 'que', 'el', 'anterior', '.', 'Yo', 'no', 'lo', 'recomiendo', '.', 'Aunque', 'había', 'fumadores', 'en', 'la', 'mesa', 'de', 'al', 'lado', 'no', 'sentimos', 'ninguna', 'molestia', 'durante', 'la', 'comida', '.', 'Hace', 'años', 'que', 'lo', 'conozco', '.', 'Por', 'ponerle', 'una', 'pega', ',', 'el', 'excesivo', ',', 'había', 'mucha', 'gente', 'y', 'en', 'la', 'sala', 'resuena', 'mucho', 'y', 'casi', 'no', 'podíamos', 'escucharnos', '.', 'en', 'peticion', 'platos', 'y', 'solucitud', 'cuenta', '.', 'Lo', 'unico', 'que', 'puedo', 'decir', 'es', 'que', 'la', 'calidad', 'de', 'lo', 'que', 'comimos', 'fue', 'estupenda', ',', 'pero', 'nos', 'sorprendio', 'la', 'cantidad', ',', 'que', 'era', 'mas', 'bien', 'escasa', '.', '(', 'casi', 'lo', 'peor', 'que', 'te', 'puede', 'pasar', 'en', 'un', 'restaurante', ')', 'Me', 'gusta', 'opinar', 'pasado', 'un', 'tiempo', ',', 'cuando', 'ya', 'has', 'asimilado', 'la', 'experiencia', '.', 'A', 'veces', 'cruda', 'en', 'algunas', 'zonas', '.', 'bueno', '.', 'La', 'ha', 'dejado', 'que', 'desear', 'en', 'todos', 'los', 'sentidos', ',', 'ha', 'sido', 'poca', 'y', 'no', 'ha', 'incluido', 'ni', 'cervezas', ',', 'con', 'lo', 'que', 'hemos', 'tenido', 'que', 'pagar', 'un', 'extra', '(', 'no', 'pequeño', ',', 'porque', 'barato', 'no', 'es', ')', 'para', 'poder', 'acabar', 'el', 'menú', 'con', 'líquido', 'con', 'el', 'que', 'hacer', 'bajar', 'un', '“', 'rissoto', '”', 'que', 'hubiera', 'hecho', 'las', 'delicias', 'del', 'presentador', 'de', 'Bricomanía', ',', 'en', 'el', 'capítulo', 'en', 'el', 'que', 'explica', 'como ...
# ['Plato', 'degustación', ':', 'un', 'poco', 'abundante', 'de', 'más', ',', 'pero', 'bien', 'cocinado', '.', 'restaurante', 'excelente', 'con', 'carne', 'de', 'alta', 'calidad', '.', 'Las', 'posibilidades', 'en', 'el', 'restaurante', 'son', 'fundamentalmente', 'tres', ';', 'carta', 'normal', ',', 'menú', 'degustacion', 'y', 'una', 'opción', 'intermedia', 'que', 'es', 'una', 'selección', 'de', 'primeros', 'y', 'postres', 'y', 'carta', 'para', 'el', 'segundo', '.', 'No', 'perderse', 'el', 'sorbete', 'de', 'mojito', '.', 'para', 'mi', 'perfecto', '!', 'Devolucion', 'a', 'cocina', ',', 'amabilidad', 'de', 'camarera', ',', 'requerimiento', 'de', 'cuenta', 'y', 'adios', '.', 'Así', 'como', 'el', 'romesco', ',', 'que', 'era', 'un', 'poco', '"', 'de', 'bote', '"', '.', 'Destacar', 'los', 'arroces', ',', 'la', 'caldereta', 'de', 'bogavante', ',', 'las', 'zamburiñas', 'al', 'horno', 'y', 'los', 'platos', 'de', '"', 'picoteo', '"', 'y', 'los', 'pescados', 'en', 'general', '.', 'Somos', 'clientes', 'asiduos', '.', 'segir', 'que', 'lo', 'bordais', 'GRACIAS', '.', 'Pedimos', 'un', 'menú', 'degustación', 'y', 'todo', 'buenísimo', '.', 'Estaría', 'bien', 'mejorar', 'la', 'calidad', 'del', 'vino', '.', 'Sin', 'duda', 'repetiremos', '.', 'Estuve', 'este', 'sabado', 'pasado', 'cenando', 'y', 'he', 'de', 'felicitar', 'tanto', 'al', 'restaurante', 'como', 'al', 'camarero', 'que', 'nos', 'atendio', 'y', 'por', 'supuesto', 'la', 'comida', '.', 'A', 'mejorar', 'baños', '.', 'Nosotros', 'ya', 'ibamos', 'con', 'la', 'idea', 'de', 'cenar', 'pizza', ',', 'y', 'nos', 'sorprendió', 'ver', 'que', 'había', 'poquita', 'variedad', '...', 'Tal', 'vez', 'la', 'única', 'pega', '(', 'para', 'mi', 'gusto', ')', 'es', 'que', 'la', 'parrillada', 'de', 'carne', 'no', 'era', 'muy', 'grande', '(', 'aunque', 'sí', 'es', 'cierto', 'que', 'te', 'dejaban', 'repetir', 'calçots', 'y', 'que', 'casi', 'todo', 'el', 'mundo', 'estaba', 'lleno', 'ya', ')', '.', 'Menú', 'calçotada', 'muy', 'bien', ',', 'dejando', 'repetir', ',', 'buena', 'relación', 'calidad-precio-calidad', '.', 'Interesante', 'restaurante', 'en', 'el', 'Born', ',', 'gran', 'calidad', 'en', 'el', 'producto', 'utilizado', ',', 'tal', 'vez', 'el', 'único', 'pero', 'sería', 'que', 'la', 'sala', 'es', 'un', 'poco', 'ruidosa', 'y', 'las', 'mesas', 'están', 'un', 'poco', 'próximas', 'entre', 'sí', '.', 'Un', 'saludo', '.', 'Servicio', '-', '4', '(', 'Nos', 'sentimos', 'un', 'poco', 'invisibles', 'por', 'el', 'personal', ',', 'simplemente', 'se', 'dedicaron', 'a', 'servir', 'la', 'comida', '.', 'Muy', 'bueno', ',', 'calidad', ',', 'servicio', 'que', 'justifican', 'su', 'precio', '.', 'La', 'decoración', 'bastante', 'conseguida', '.', 'Para', 'finalizar', 'con', 'los', 'previos', 'antes', 'de', 'entrar', 'con', 'la', 'comida', 'un', 'comentario', ':', 'un', 'poquito', 'de', 'musica', 'de', 'ambiente', 'daria', 'intimidad', ',', 'se', 'oia', 'todo', 'lo', 'que', 'se', 'decia', 'en', 'las', 'otras', '5', 'mesas', 'que', 'estaban', 'ocupadas', '(', 'todas', 'ellas', 'con', 'parejas', 'con', 'cupones', 'de', 'descuento', 'como', 'nosotros', ')', '.', 'El', 'trato', 'amable', ',', 'y', 'el', 'servicio', 'rápido', '.', 'Al', 'principio', 'nos', 'parecieron', 'un', 'poco', 'bruscos', 'y', 'habiendo', 'reservado', 'nos', 'iban', 'a', 'dar', 'la', 'peor', 'mesa', 'del', 'restaurante', '.', 'Hasta', 'las', '16h15', 'no', 'nos', 'adjudicaron', 'la', 'mesa', '.', 'Situación', 'excelente', '.', 'Estupendo', 'el', 'arroz', 'caldoso', 'con', 'bogavante', 'y', 'muy', 'buen', 'trato', '.', 'Conjuga', 'perfectamente', 'calidad', ',', 'servicio', 'y', 'ambiente', '.', '<+>', 'personal', 'amable', '.', 'Una', 'pena', 'para', 'las', 'instalaciones', 'tan', 'excelentes', 'que', 'hay', '.', 'Incluso', 'no', 'entendemos', 'porque', 'hicimos', 'la', 'reserva', 'porque', 'la', 'cola', 'la', 'sufrimos', 'igual', '.', 'Es', 'decir', ',', 'un', 'restaurante', ',', 'cuando', 'estás', 'satisfecho', ',', 'tienes', 'ganas', 'de', 'volver', '.', 'Entre', ' ...
# {'B-positive': ['Plato', 'restaurante', 'carne', 'sorbete', 'camarera', 'arroces', 'caldereta', 'zamburiñas', 'platos', 'pescados', 'menú', 'restaurante', 'camarero', 'comida', 'calçots', 'restaurante', 'producto', 'decoración', 'trato', 'Situación', 'arroz', 'trato', 'servicio', 'ambiente', 'personal', 'Arróz', 'ambiente', 'servicio', 'carta', 'comida', 'servicio', 'sitio', 'servicio', 'comida', 'comida', 'servicio', 'servicio', 'ambiente', 'comida', 'tomate', 'Lugar', 'calçotada', 'calçots', 'bebida', 'comida', 'servicio', 'restaurante', 'restaurante', 'servicio', 'Servicio', 'Servicio', 'comida', 'restaurante', 'Servicio', 'comida', 'servicio', 'ambiente', 'amabilidad', 'sitio', 'comida', 'Un', 'servicio', 'comida', 'materia', 'Tarta', 'platos', 'lugar', 'situación', 'carne', 'servicio', 'servicio', 'comida', 'lugar', 'platos', 'pescado', 'comida', 'terraza', 'servicio', 'comida', 'cocinero', 'tartar', 'postres', 'servicio', 'comida', 'localización', 'carnes', 'servicio', 'platos', 'entrantes', 'servicio', 'comida', 'carne', 'CARTA', 'Comida', 'vistas', 'lugar', 'comida', 'servicio', 'comida', 'servicio', 'productos', 'trato', 'Ambiente', 'restaurante', 'menú', 'trato', 'Restaurante', 'carta', 'carnes', 'especialidades', 'ambiente', 'servicio', 'Servicio', 'sopa', 'comida', 'pescaditos', 'paella', 'trato', 'comida', 'presentación', 'comida', 'sito', 'comida', 'producto', 'servicio', 'vinos', 'Comida', 'servicio', 'atención', 'comida', 'restaurante', 'pianista', 'comida', 'lugar', 'jamon', 'Comida', 'vistas', 'Personal', 'alimentos', 'menu', 'ambiente', 'camareros', 'ambiente', 'servicio', 'platos', 'restaurantes', 'Recomendable', 'servicio', 'SERVICIO', 'chocolate', 'platos', 'menú', 'cabrito', 'Lugar', 'churrasco', 'patatas', 'comer', 'servicio', 'camareros', 'calçotada'], 'I-positive': ['degustación', 'de', 'mojito', 'de', 'bogavante', 'al', 'horno', 'de', '"', 'picoteo', 'degustación', 'caldoso', 'con', 'bogavante', 'en', 'texturas', 'mediterranea', 'valor', 'seguro', 'prima', 'de', 'manzana', 'de', 'lubina', 'de', 'arroz', 'DE', 'VINOS', 'de', 'su', 'personal', 'para', 'niños', 'de', 'cebolla', 'fritos', 'del', 'personal', 'infantil', 'totalmente', '.', 'de', 'los', 'postres', 'temático', 'de', 'la', 'trufa', 'fritas'], 'O': [':', 'un', 'poco', 'abundante', 'de', 'más', ',', 'pero', 'bien', 'cocinado', '.', 'excelente', 'con', 'de', 'alta', 'calidad', '.', 'Las', 'posibilidades', 'en', 'el', 'restaurante', 'son', 'fundamentalmente', 'tres', ';', 'carta', 'normal', ',', 'menú', 'degustacion', 'y', 'una', 'opción', 'intermedia', 'que', 'es', 'una', 'selección', 'de', 'primeros', 'y', 'postres', 'y', 'carta', 'para', 'el', 'segundo', '.', 'No', 'perderse', 'el', '.', 'para', 'mi', 'perfecto', '!', 'Devolucion', 'a', 'cocina', ',', 'amabilidad', 'de', ',', 'requerimiento', 'de', 'cuenta', 'y', 'adios', '.', 'Así', 'como', 'el', ',', 'que', 'era', 'un', 'poco', '"', 'de', 'bote', '"', '.', 'Destacar', 'los', ',', 'la', ',', 'las', 'y', 'los', '"', 'y', 'los', 'en', 'general', '.', 'Somos', 'clientes', 'asiduos', '.', 'segir', 'que', 'lo', 'bordais', 'GRACIAS', '.', 'Pedimos', 'un', 'y', 'todo', 'buenísimo', '.', 'Estaría', 'bien', 'mejorar', 'la', 'calidad', 'del', '.', 'Sin', 'duda', 'repetiremos', '.', 'Estuve', 'este', 'sabado', 'pasado', 'cenando', 'y', 'he', 'de', 'felicitar', 'tanto', 'al', 'como', 'al', 'que', 'nos', 'atendio', 'y', 'por', 'supuesto', 'la', '.', 'A', 'mejorar', '.', 'Nosotros', 'ya', 'ibamos', 'con', 'la', 'idea', 'de', 'cenar', 'pizza', ',', 'y', 'nos', 'sorprendió', 'ver', 'que', 'había', 'poquita', '...', 'Tal', 'vez', 'la', 'única', 'pega', '(', 'para', 'mi', 'gusto', ')', 'es', 'que', 'la', 'no', 'era', 'muy', 'grande', '(', 'aunque', 'sí', 'es', 'cierto', 'que', 'te', 'dejaban', 'repetir', 'y', 'que', 'casi', 'todo', 'el', 'mundo', 'estaba', 'lleno', 'ya', ')', '.', 'Menú', 'calçotada', 'muy', 'bien', ',', 'dejando', 'repetir', ',', 'buena', 'relación', 'calidad-precio-calidad', '.', 'Interesant ...

# %% [markdown]
# ## 2.1 Calculating MLE
# #### **Calculating Emission Parameters**

# %%
# def clean_dataset(dataset):
#     emissions = []
#     states = {"B-positive":[], "B-negative":[], "B-neutral":[], "I-positive":[], "I-negative":[], "I-neutral":[], "O":[]}
#     states_no = {"B-positive":0, "B-negative":0, "B-neutral":0, "I-positive":0,  "I-negative":0,  "I-neutral":0, "O":0}
#     emission_pairs = {}
#     state_emission = dataset.split("\n")
#     filtered_state_emission= [word for word in state_emission if word.strip()!= ""]
#     pairs = [tuple(pair.split()) for pair in filtered_state_emission]

#     for pair in pairs:
#         states[pair[1]].append(pair[0])
#         if pair[0] not in states.keys():
#             emissions.append(pair[0])
#         if pair in emission_pairs.keys():
#             emission_pairs[pair] += 1
#         elif pair not in emission_pairs.keys():
#             emission_pairs.update({pair:1})
#     for key,value in states.items():
#         states_no[key] = len(value)
#     return emissions, states, states_no, emission_pairs
# emissions, states, states_no, emission_pairs = clean_dataset(ES_train)

# %%
def get_emissionparams(data):
    # emission_parameters = dict(data)
    label_counts = {key : len(value) for key,value in data.items()}
    emission_counts= {}
    for key, value in data.items():
        word_counts = Counter(value)
        emission_counts.update({key: dict(word_counts)})
    # for label, word in emission_counts.items():
    #     count_y = label_counts.get(label)
    #     for label, count_y_x in word.items():
    #         emission_params = count_y_x/(count_y)
            # word.update({label:emission_params})
    def e(y,x):
        # return emission_counts.get(y).get(x)
        print(emission_counts[y][x])
        print(label_counts[y])
        return emission_counts[y][x]/label_counts[y]
    return e

e = get_emissionparams(ES_train)
# print(e('I-neutral',':'))
print(e('O',':'))
# print(emission_parameters("O",'Estuvimos'))
# Out:
# 68
# 29035
# 0.00234200103323575

# %% [markdown]
# ## 2.2 Calculating MLE
# #### **Calculating Emission Parameters with fixes**

# %%
def get_emissionparams(data, token=1):
    words = list(set(word for word_list in data.values() for word in word_list))
    print(words)
    label_counts = {key : len(value) for key,value in data.items()}
    emission_counts= {}
    for key, value in data.items():
        word_counts = Counter(value)
        emission_counts.update({key: dict(word_counts)})
    # for label, word in emission_counts.items():
    #     count_y = label_counts.get(label)
    #     for label, count_y_x in word.items():
    #         emission_params = count_y_x/(count_y)
    #         word.update({label:emission_params})
    def e(y,x):
            if emission_counts.get(y).get(x):
                return emission_counts[y][x]/(label_counts[y]+token)
            elif x not in words:
                # emission_params = token/label_counts.get(y)
                # emission_counts[y].update({"#UNK#":emission_params})
                # x = "#UNK#"
                # return emission_counts.get(y).get(x)
                return token/(label_counts[y] + token)
            else:
                 return 0
    return e

# print(get_emissionparams(ES_train,1,'O', 'MISSING',"specific"))
# print(get_emissionparams(ES_train))

e = get_emissionparams(ES_train)
print(e('I-neutral',':'))
print(e('O',':'))
# Out:
# ['dejaban', 'JoséEn', 'hoja', 'pasan', 'york', 'flaco', 'sótano', 'cafés', 'gustado', 'City', 'acogedora', 'deducimos', 'podemos', 'faciles', 'trato', 'molesten', 'Normalito', 'xmenez', 'está', 'adaptarse', 'maxima', 'extraordinario', 'continuación', 'negocio', 'agradableLa', 'abundancia', 'Cocina', 'meccano', 'Hacia', 'raro', 'tratamientos', 'Sobre', 'equilibradas', 'izquierda', 'circuito', 'gracia', 'lugares', 'zona', 'Plato', 'Reyes', 'servirlos.Por', 'agarrado', 'escucharnos', 'puedas', 'invitaran', 'Jose', 'paellas', 'fiasco', 'agobiante', 'indicado', 'famoso', 'presentamos', 'Ofrecen', 'quiseran', 'inmejorables', 'novio', 'secos', 'coloreada', 'formar', 'Fui', 'demasiado', 'paredes', 'tintorro', 'diminuto', 'establecimiento', 'Agradable', 'faltaban', 'carpaccio', 'típica', 'salgo', 'rapido', 'sus', 'quizás', 'agusto', 'favor', 'porqeu', 'par', 'óptimo', 'compuesto', 'prisas', 'parrilla', 'Chef', 'preferido', 'tuvieron', 'puntuales', 'nuestros', 'pizz', 'advertimos', 'mas', 'cliente', 'apreciación', 'microondas', 'reservaron', 'comodos', 'vista', 'pasó', 'cantidades', 'flojita', 'esas', 'conocer', 'conservadas', 'Homogeneidad', 'fíjese', 'platos', 'rematar', 'apropiados', 'ellas', 'compañeros', 'En', 'pague', 'sidral', 'detallista', 'siempre', 'predilecto', 'escasos', 'habremos', 'Ubicación', 'Seguid', 'vi', 'poquito', 'Despensa', 'localización', 'saborea', 'Rapido', 'rebozado', 'probarlo', 'pedro', 'podía', 'Nunca', 'cena-espectáculo', 'constó', 'responda', 'quedamos', 'Lluvia', 'parque', 'lugar', 'traido', 'tomado', 'Olivé', 'pequeña', 'talla', 'xato', 'Jornadas', 'entra', 'comido', 'ambientacion', 'altura', 'realidad', 'producto', 'algunos', 'Berasategui', 'personales', '22', 'dorada', 'incomible', 'existencia', 'dió', 'platitos', 'corren', 'tradición', 'bastantes', 'homenaje', '5J', 'esperamos', '[', 'agradable', 'jueves', 'paciencia', 'pakistaní', 'supongo', 'creativas', 'flojo', '10,0', 'pasaron', 'ironía', 'impecable', 'originarl', 'pedi', 'sencillamente', 'reclamaciones', 'comida.El', 'gusto', 'repetiremos', 'mercado', 'servidas', 'cerezas', 'Asi', 'especial', 'legales', 'comiendo', 'muchisimos', 'total', 'prefabricada', 'huelva', 'Web', 'pagarlo', 'disculpan', 'tendremos', 'transporte', 'limpieza', 'cada', 'instalaciones', 'decidimos', 'alquel', 'albahaca', 'acelerados', 'cambiaran', 'colmenillas', 'invade', 'hola', '<+>', 'realcion', 'llenaron', 'médula', 'PERFECCIÓN', '5,5', 'correcto', 'escasa', 'ágil', 'Ayles', 'alterados', 'Escriba', 'emergencias', 'panes', 'comi', 'debe', 'comportamiento', 'amabilidad', 'ventanales', 'creerme', 'sobre', 'revisar', 'aireado', 'coche', 'compañia', 'merecería', 'pinchos', 'tras', 'seguro.En', 'encendido', 'manteles', 'descamar', 'Nefastos', 'compartir', 'menú', 'discrepo', 'tonta', 'invita', 'desayunos', 'espacio', 'eficiente', 'Continuamos', 'Frances', 'accesos', 'chasco', 'vergonzoso', 'sabe', 'ofrece', 'principal', 'bañandonos', 'guitarra.Resumiendo', 'crisis', 'coco', 'tan', 'conservadoras', 'tostaditas', 'Tacita', 'cuarta', 'nuestro', 'respeto', 'carajillo', 'Luis', 'hermoso', 'hiciera', 'cueste', 'faena', 'advertirnos', 'casa', 'preparan', 'cobrarnos', 'JoséHe', 'inteligencia', 'salon', 'langostinos', 'filete', 'experiencias', 'riquísimos', 'born', 'itios', 'calidad-precioLo', 'Se', 'habíamos', 'puntuacion', 'limon', 'pediomos', 'despedirnos', 'don', 'nos', 'optar', 'oportunamente', '175', 'mirabamos', 'Vas', 'DecepcionanteCon', 'desgustación', 'miniatura', 'Riojas', 'como', 'nuevos', 'narices', 'pinta', 'CARTA', 'iberico', 'podíamos', 'que', 'trabajador', 'pastas', 'calificar', 'LO', 'fascino', 'apartado', 'tinglado', 'myuy', 'para', 'sabrosísimo', 'rellenas', 'cordero', 'SERVICIO', 'rellena', 'egundos', 'tiempo', 'cuidado', 'aqui', 'elwccion', 'comprendí', 'enseguida', 'noches', 'variados', 'taberna', 'mantienen', 'personas', 'Empiezo', 'cene', 'numerosos', 'refrescos', 'bailar.La', 'Cachirulo', 'escasas', 'asi', 'delicado', 'retórica', 'Actuaban', 'BADAJOZ', 'fueramos ...
# 0
# 0.00234192037470726

# %% [markdown]
# ## 2.3 Simple Sentiment Analysis
# #### **Implementing a simple sentiment analysis system**

# %%
def simple_sentiment(dataset, train_set,output_path):
    e = get_emissionparams(train_set)
    out = open(output_path, "w", encoding="utf-8")
    output=[]
    for word in dataset:
        max_p = 0
        label = None
        for key in train_set.keys():
            p = e(key,word)
            if e(key,word) > max_p:
                max_p = p
                label = key
        if word == ".":
            output_str = " ".join([word, label, "\n","\n"])
        else:
            output_str = " ".join([word, label, "\n"])
        out.write(output_str)

        #e(all the states, word) find the highest e
        # store the {word: highest e}
        
simple_sentiment(ES_dev,ES_train,"Data/ES/dev.p1.out")
# Out:
# ['dejaban', 'JoséEn', 'hoja', 'pasan', 'york', 'flaco', 'sótano', 'cafés', 'gustado', 'City', 'acogedora', 'deducimos', 'podemos', 'faciles', 'trato', 'molesten', 'Normalito', 'xmenez', 'está', 'adaptarse', 'maxima', 'extraordinario', 'continuación', 'negocio', 'agradableLa', 'abundancia', 'Cocina', 'meccano', 'Hacia', 'raro', 'tratamientos', 'Sobre', 'equilibradas', 'izquierda', 'circuito', 'gracia', 'lugares', 'zona', 'Plato', 'Reyes', 'servirlos.Por', 'agarrado', 'escucharnos', 'puedas', 'invitaran', 'Jose', 'paellas', 'fiasco', 'agobiante', 'indicado', 'famoso', 'presentamos', 'Ofrecen', 'quiseran', 'inmejorables', 'novio', 'secos', 'coloreada', 'formar', 'Fui', 'demasiado', 'paredes', 'tintorro', 'diminuto', 'establecimiento', 'Agradable', 'faltaban', 'carpaccio', 'típica', 'salgo', 'rapido', 'sus', 'quizás', 'agusto', 'favor', 'porqeu', 'par', 'óptimo', 'compuesto', 'prisas', 'parrilla', 'Chef', 'preferido', 'tuvieron', 'puntuales', 'nuestros', 'pizz', 'advertimos', 'mas', 'cliente', 'apreciación', 'microondas', 'reservaron', 'comodos', 'vista', 'pasó', 'cantidades', 'flojita', 'esas', 'conocer', 'conservadas', 'Homogeneidad', 'fíjese', 'platos', 'rematar', 'apropiados', 'ellas', 'compañeros', 'En', 'pague', 'sidral', 'detallista', 'siempre', 'predilecto', 'escasos', 'habremos', 'Ubicación', 'Seguid', 'vi', 'poquito', 'Despensa', 'localización', 'saborea', 'Rapido', 'rebozado', 'probarlo', 'pedro', 'podía', 'Nunca', 'cena-espectáculo', 'constó', 'responda', 'quedamos', 'Lluvia', 'parque', 'lugar', 'traido', 'tomado', 'Olivé', 'pequeña', 'talla', 'xato', 'Jornadas', 'entra', 'comido', 'ambientacion', 'altura', 'realidad', 'producto', 'algunos', 'Berasategui', 'personales', '22', 'dorada', 'incomible', 'existencia', 'dió', 'platitos', 'corren', 'tradición', 'bastantes', 'homenaje', '5J', 'esperamos', '[', 'agradable', 'jueves', 'paciencia', 'pakistaní', 'supongo', 'creativas', 'flojo', '10,0', 'pasaron', 'ironía', 'impecable', 'originarl', 'pedi', 'sencillamente', 'reclamaciones', 'comida.El', 'gusto', 'repetiremos', 'mercado', 'servidas', 'cerezas', 'Asi', 'especial', 'legales', 'comiendo', 'muchisimos', 'total', 'prefabricada', 'huelva', 'Web', 'pagarlo', 'disculpan', 'tendremos', 'transporte', 'limpieza', 'cada', 'instalaciones', 'decidimos', 'alquel', 'albahaca', 'acelerados', 'cambiaran', 'colmenillas', 'invade', 'hola', '<+>', 'realcion', 'llenaron', 'médula', 'PERFECCIÓN', '5,5', 'correcto', 'escasa', 'ágil', 'Ayles', 'alterados', 'Escriba', 'emergencias', 'panes', 'comi', 'debe', 'comportamiento', 'amabilidad', 'ventanales', 'creerme', 'sobre', 'revisar', 'aireado', 'coche', 'compañia', 'merecería', 'pinchos', 'tras', 'seguro.En', 'encendido', 'manteles', 'descamar', 'Nefastos', 'compartir', 'menú', 'discrepo', 'tonta', 'invita', 'desayunos', 'espacio', 'eficiente', 'Continuamos', 'Frances', 'accesos', 'chasco', 'vergonzoso', 'sabe', 'ofrece', 'principal', 'bañandonos', 'guitarra.Resumiendo', 'crisis', 'coco', 'tan', 'conservadoras', 'tostaditas', 'Tacita', 'cuarta', 'nuestro', 'respeto', 'carajillo', 'Luis', 'hermoso', 'hiciera', 'cueste', 'faena', 'advertirnos', 'casa', 'preparan', 'cobrarnos', 'JoséHe', 'inteligencia', 'salon', 'langostinos', 'filete', 'experiencias', 'riquísimos', 'born', 'itios', 'calidad-precioLo', 'Se', 'habíamos', 'puntuacion', 'limon', 'pediomos', 'despedirnos', 'don', 'nos', 'optar', 'oportunamente', '175', 'mirabamos', 'Vas', 'DecepcionanteCon', 'desgustación', 'miniatura', 'Riojas', 'como', 'nuevos', 'narices', 'pinta', 'CARTA', 'iberico', 'podíamos', 'que', 'trabajador', 'pastas', 'calificar', 'LO', 'fascino', 'apartado', 'tinglado', 'myuy', 'para', 'sabrosísimo', 'rellenas', 'cordero', 'SERVICIO', 'rellena', 'egundos', 'tiempo', 'cuidado', 'aqui', 'elwccion', 'comprendí', 'enseguida', 'noches', 'variados', 'taberna', 'mantienen', 'personas', 'Empiezo', 'cene', 'numerosos', 'refrescos', 'bailar.La', 'Cachirulo', 'escasas', 'asi', 'delicado', 'retórica', 'Actuaban', 'BADAJOZ', 'fueramos ...
# ['dejaban', 'JoséEn', 'hoja', 'pasan', 'york', 'flaco', 'sótano', 'cafés', 'gustado', 'City', 'acogedora', 'deducimos', 'podemos', 'faciles', 'trato', 'molesten', 'Normalito', 'xmenez', 'está', 'adaptarse', 'maxima', 'extraordinario', 'continuación', 'negocio', 'agradableLa', 'abundancia', 'Cocina', 'meccano', 'Hacia', 'raro', 'tratamientos', 'Sobre', 'equilibradas', 'izquierda', 'circuito', 'gracia', 'lugares', 'zona', 'Plato', 'Reyes', 'servirlos.Por', 'agarrado', 'escucharnos', 'puedas', 'invitaran', 'Jose', 'paellas', 'fiasco', 'agobiante', 'indicado', 'famoso', 'presentamos', 'Ofrecen', 'quiseran', 'inmejorables', 'novio', 'secos', 'coloreada', 'formar', 'Fui', 'demasiado', 'paredes', 'tintorro', 'diminuto', 'establecimiento', 'Agradable', 'faltaban', 'carpaccio', 'típica', 'salgo', 'rapido', 'sus', 'quizás', 'agusto', 'favor', 'porqeu', 'par', 'óptimo', 'compuesto', 'prisas', 'parrilla', 'Chef', 'preferido', 'tuvieron', 'puntuales', 'nuestros', 'pizz', 'advertimos', 'mas', 'cliente', 'apreciación', 'microondas', 'reservaron', 'comodos', 'vista', 'pasó', 'cantidades', 'flojita', 'esas', 'conocer', 'conservadas', 'Homogeneidad', 'fíjese', 'platos', 'rematar', 'apropiados', 'ellas', 'compañeros', 'En', 'pague', 'sidral', 'detallista', 'siempre', 'predilecto', 'escasos', 'habremos', 'Ubicación', 'Seguid', 'vi', 'poquito', 'Despensa', 'localización', 'saborea', 'Rapido', 'rebozado', 'probarlo', 'pedro', 'podía', 'Nunca', 'cena-espectáculo', 'constó', 'responda', 'quedamos', 'Lluvia', 'parque', 'lugar', 'traido', 'tomado', 'Olivé', 'pequeña', 'talla', 'xato', 'Jornadas', 'entra', 'comido', 'ambientacion', 'altura', 'realidad', 'producto', 'algunos', 'Berasategui', 'personales', '22', 'dorada', 'incomible', 'existencia', 'dió', 'platitos', 'corren', 'tradición', 'bastantes', 'homenaje', '5J', 'esperamos', '[', 'agradable', 'jueves', 'paciencia', 'pakistaní', 'supongo', 'creativas', 'flojo', '10,0', 'pasaron', 'ironía', 'impecable', 'originarl', 'pedi', 'sencillamente', 'reclamaciones', 'comida.El', 'gusto', 'repetiremos', 'mercado', 'servidas', 'cerezas', 'Asi', 'especial', 'legales', 'comiendo', 'muchisimos', 'total', 'prefabricada', 'huelva', 'Web', 'pagarlo', 'disculpan', 'tendremos', 'transporte', 'limpieza', 'cada', 'instalaciones', 'decidimos', 'alquel', 'albahaca', 'acelerados', 'cambiaran', 'colmenillas', 'invade', 'hola', '<+>', 'realcion', 'llenaron', 'médula', 'PERFECCIÓN', '5,5', 'correcto', 'escasa', 'ágil', 'Ayles', 'alterados', 'Escriba', 'emergencias', 'panes', 'comi', 'debe', 'comportamiento', 'amabilidad', 'ventanales', 'creerme', 'sobre', 'revisar', 'aireado', 'coche', 'compañia', 'merecería', 'pinchos', 'tras', 'seguro.En', 'encendido', 'manteles', 'descamar', 'Nefastos', 'compartir', 'menú', 'discrepo', 'tonta', 'invita', 'desayunos', 'espacio', 'eficiente', 'Continuamos', 'Frances', 'accesos', 'chasco', 'vergonzoso', 'sabe', 'ofrece', 'principal', 'bañandonos', 'guitarra.Resumiendo', 'crisis', 'coco', 'tan', 'conservadoras', 'tostaditas', 'Tacita', 'cuarta', 'nuestro', 'respeto', 'carajillo', 'Luis', 'hermoso', 'hiciera', 'cueste', 'faena', 'advertirnos', 'casa', 'preparan', 'cobrarnos', 'JoséHe', 'inteligencia', 'salon', 'langostinos', 'filete', 'experiencias', 'riquísimos', 'born', 'itios', 'calidad-precioLo', 'Se', 'habíamos', 'puntuacion', 'limon', 'pediomos', 'despedirnos', 'don', 'nos', 'optar', 'oportunamente', '175', 'mirabamos', 'Vas', 'DecepcionanteCon', 'desgustación', 'miniatura', 'Riojas', 'como', 'nuevos', 'narices', 'pinta', 'CARTA', 'iberico', 'podíamos', 'que', 'trabajador', 'pastas', 'calificar', 'LO', 'fascino', 'apartado', 'tinglado', 'myuy', 'para', 'sabrosísimo', 'rellenas', 'cordero', 'SERVICIO', 'rellena', 'egundos', 'tiempo', 'cuidado', 'aqui', 'elwccion', 'comprendí', 'enseguida', 'noches', 'variados', 'taberna', 'mantienen', 'personas', 'Empiezo', 'cene', 'numerosos', 'refrescos', 'bailar.La', 'Cachirulo', 'escasas', 'asi', 'delicado', 'retórica', 'Actuaban', 'BADAJOZ', 'fueramos ...
